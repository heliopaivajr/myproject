# %%
import duckdb

# %%
con = duckdb.connect(database='dados_duckdb.db', read_only=False)

# %%
df = con.execute("SELECT * FROM produtos").fetchdf()
df.head(10)

# %%
df2 = df.drop(columns=['id_categoria', 'id_fornecedor'])
df2.head(10)

# %%
con.execute("""
    CREATE TABLE IF NOT EXISTS dim_produtos (
        id_produto BIGINT,
        nm_produto TEXT,
        vl_preco FLOAT
        )
""")

# %%
df2.head(10)

# %%
con.execute ("INSERT INTO dim_produtos SELECT * FROM df2")

# %%
df_dim = con.execute("SELECT * FROM dim_git rm --cached "scripts/dados_duckdb.db"produtos").fetchdf()
df_dim.head(10)

# %% [markdown]
# DELETAR TABELA É con.execute(""" DROP TABLE dim_produtos """)

# %%
con.close()
